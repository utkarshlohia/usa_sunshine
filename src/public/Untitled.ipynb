# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/utkarshlohia/Desktop/my-heatmap-project/public/india_weather.csv")
df['date'].unique()
# Out:
# array(['2020-01-01', '2020-01-02', '2020-01-03', ..., '2023-09-03',
#        '2023-09-04', '2023-09-05'], dtype=object)

# %%
pip install pandas pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
file_path = '/Users/utkarshlohia/Desktop/archive (1)/daily_weather.parquet'

# Read the Parquet file into a DataFrame
raw_df = pd.read_parquet(file_path, engine='pyarrow')  # or engine='fastparquet'

# %%
raw_df['date'] = pd.to_datetime(raw_df['date'])

# %%
cities_df = pd.read_csv('/Users/utkarshlohia/Desktop/archive (1)/cities.csv')
cities_df
# Out:
#      station_id    city_name      country       state iso2 iso3   latitude  \
# 0         41515     Asadabad  Afghanistan       Kunar   AF  AFG  34.866000
# 1         38954     Fayzabad  Afghanistan  Badakhshan   AF  AFG  37.129761
# 2         41560    Jalalabad  Afghanistan   Nangarhar   AF  AFG  34.441527
# 3         38947       Kunduz  Afghanistan      Kunduz   AF  AFG  36.727951
# 4         38987   Qala i Naw  Afghanistan     Badghis   AF  AFG  34.983000
# ...         ...          ...          ...         ...  ...  ...        ...
# 1240      67475       Kasama       Zambia    Northern   ZM  ZMB -10.199598
# 1241      68030  Livingstone       Zambia    Southern   ZM  ZMB -17.860009
# 1242      67633        Mongu       Zambia     Western   ZM  ZMB -15.279598
# 1243      67775       Harare     Zimbabwe      Harare   ZW  ZWE -17.817790
# 1244      67975     Masvingo     Zimbabwe    Masvingo   ZW  ZWE -20.059617
#
#       longitude
# 0     71.150005
# 1     70.579247
# ...

# %%
new_raw_df = raw_df[(raw_df['date'].dt.year > 2000)]
new_raw_df = new_raw_df[(new_raw_df['date'].dt.year < 2023)]
merged_df = new_raw_df.merge(cities_df, on='city_name')
merged_df = merged_df[merged_df['country'] == 'India']

# %%
new_merged_df = merged_df[['city_name', 'date', 'sunshine_total_min', 'latitude', 'longitude']]

# %%
new_merged_df['sunshine_total_min'].isna().sum()
# Out:
# 200113

# %%
merged_df
# Out:
#         station_id_x           city_name       date  season  avg_temp_c  \
# 2845752        42724            Agartala 2001-01-01  Winter        20.4
# 2845753        42724            Agartala 2001-01-02  Winter        20.5
# 2845754        42724            Agartala 2001-01-03  Winter        20.0
# 2845755        42724            Agartala 2001-01-04  Winter        16.1
# 2845756        42724            Agartala 2001-01-05  Winter        14.3
# ...              ...                 ...        ...     ...         ...
# 3045860        43371  Thiruvananthapuram 2022-12-27  Winter        27.0
# 3045861        43371  Thiruvananthapuram 2022-12-28  Winter        27.1
# 3045862        43371  Thiruvananthapuram 2022-12-29  Winter        27.0
# 3045863        43371  Thiruvananthapuram 2022-12-30  Winter        27.3
# 3045864        43371  Thiruvananthapuram 2022-12-31  Winter        26.9
#
#          min_temp_c  max_temp_c  precipitation_mm  snow_depth_mm  \
# ...

# %%
old_df = pd.read_csv('/Users/utkarshlohia/Desktop/my-heatmap-project/public/india_weather.csv')
old_df = old_df.iloc[:, 1:]
old_df.columns = ['station_id', 'date', 'avg_temp_c', 'name', 'latitude',
       'longitude']
old_df.to_csv('/Users/utkarshlohia/Desktop/my-heatmap-project/public/india_weather.csv')

# %%
old_df
# Out:
#        station_id        date  avg_temp_c                name   latitude  \
# 0           42724  2020-01-01        21.4            Agartala  23.835404
# 1           42724  2020-01-02        20.9            Agartala  23.835404
# 2           42724  2020-01-03        17.9            Agartala  23.835404
# 3           42724  2020-01-04        20.3            Agartala  23.835404
# 4           42724  2020-01-05        18.5            Agartala  23.835404
# ...           ...         ...         ...                 ...        ...
# 38738       43371  2023-09-01        28.0  Thiruvananthapuram   8.499984
# 38739       43371  2023-09-02        27.8  Thiruvananthapuram   8.499984
# 38740       43371  2023-09-03        27.8  Thiruvananthapuram   8.499984
# 38741       43371  2023-09-04        27.8  Thiruvananthapuram   8.499984
# 38742       43371  2023-09-05        27.7  Thiruvananthapuram   8.499984
#
#        longitude
# 0      91.279999
# 1      91.279999
# 2      91.279999
# 3      91.279999
# ...
